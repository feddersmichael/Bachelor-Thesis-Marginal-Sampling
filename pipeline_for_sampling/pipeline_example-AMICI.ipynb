# %%
import pypesto
import pypesto.petab
import pypesto.optimize as optimize
import pypesto.sample as sample
import pypesto.visualize as visualize

import petab
import numpy as np
import scipy
import pickle

from amici.petab_import import import_petab_problem
from amici.petab_objective import simulate_petab

# import to petab
petab_problem = petab.Problem.from_yaml(
    "conversion_reaction/SS_conversion_reaction.yaml")
# import to pypesto
importer = pypesto.petab.PetabImporter(petab_problem) #PetabImporter class-object (subclass of AmiciObjectBuilder)
# create problem
problem = importer.create_problem(guess_steadystate=False) #pypesto.problem class-object

amici_model = import_petab_problem(petab_problem) 

my_internal_amici_objective = importer.create_objective() #pypesto.AmiciObjective class-object
# Out:
# 2020-10-27 13:09:25.883 - amici.petab_import - INFO - Importing model ...
# 2020-10-27 13:09:25.899 - amici.petab_import - INFO - Model name is 'conversion_reaction_0'.
# Writing model code to 'C:\Users\fedde\PycharmProjects\Bachelor-Thesis-Marginal-Sampling\pipeline_for_sampling\amici_models\conversion_reaction_0'.
# 2020-10-27 13:09:25.899 - amici.petab_import - INFO - Species: 2
# 2020-10-27 13:09:25.899 - amici.petab_import - INFO - Global parameters: 2
# 2020-10-27 13:09:25.899 - amici.petab_import - INFO - Reactions: 2
# 2020-10-27 13:09:25.968 - amici.petab_import - INFO - Observables: 1
# 2020-10-27 13:09:25.968 - amici.petab_import - INFO - Sigmas: 1
# 2020-10-27 13:09:25.968 - amici.petab_import - DEBUG - Adding output parameters to model: OrderedDict([('observableParameter1_obs_b', None), ('noiseParameter1_obs_b', None)])
# 2020-10-27 13:09:25.968 - amici.petab_import - DEBUG - Condition table: (1, 0)
# 2020-10-27 13:09:25.968 - amici.petab_import - DEBUG - Fixed parameters are []
# 2020-10-27 13:09:25.968 - amici.petab_import - INFO - Overall fixed parameters: 0
# 2020-10-27 13:09:25.968 - amici.petab_import - INFO - Variable parameters: 4
# 2020-10-27 13:09:25.999 - amici.sbml_import - INFO - Finished processing SBML parameters          + (2.51E-04s)
# 2020-10-27 13:09:26.030 - amici.sbml_import - INFO - Finished processing SBML compartments        + (2.46E-04s)
# 2020-10-27 13:09:26.037 - amici.sbml_import - INFO - Finished processing SBML species             + (9.07E-04s)
# 2020-10-27 13:09:26.083 - amici.sbml_import - INFO - Finished processing SBML reactions           + (1.71E-02s)
# 2020-10-27 13:09:26.099 - amici.sbml_import - INFO - Finished processing SBML rules               + (2.11E-04s)
# 2020-10-27 13:09:26.137 - amici.sbml_import - INFO - Finished processing SBML observables         + (1.96E-02s)
# 2020-10-27 13:09:26.184 - amici.ode_export - INFO - Finished running smart_multiply              ++ (1.03E-03s)
# 2020-10-27 13:09:26.184 - amici.ode_export - INFO - Finished importing SbmlImporter               + (2.65E-02s)
# 2020-10-27 13:09:26.253 - amici.ode_export - INFO - Finished simplifying Jy                    ++++ (9.15E-03s)
# 2020-10-27 13:09:26.253 - amici.ode_export - INFO - Finished computing Jy                       +++ (2.49E-02s)
# 2020-10-27 13:09:26.284 - amici.ode_export - INFO - Finished writing Jy.cpp                      ++ (5.96E-02s)
# 2020-10-27 13:09:26.353 - amici.ode_export - INFO - Finished running smart_jacobian            ++++
# 2020-10-27 13:09:28.062 - amici.ode_export - INFO - Finished generating cpp code                  + (1.86E+00s)
# b'running build_ext\r\nChanged extra_compile_args for msvc to [\'/std:c++14\']\r\nbuilding \'conversion_reaction_0._conversion_reaction_0\' extension\r\nTesting SWIG executable swig4.0... FAILED.\r\nTesting SWIG executable swig3.0... FAILED.\r\nTesting SWIG executable swig... SUCCEEDED.\r\nswigging swig\\conversion_reaction_0.i to swig\\conversion_reaction_0_wrap.cpp\r\nC:\\swigwin-4.0.2\\swig.exe -python -c++ -modern -outdir conversion_reaction_0 -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\swig -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\include -o swig\\conversion_reaction_0_wrap.cpp swig\\conversion_reaction_0.i\r\nDeprecated command line option: -modern. This option is now always on.\r\ncreating build\r\ncreating build\\temp.win-amd64-3.8\r\ncreating build\\temp.win-amd64-3.8\\Release\r\ncreating build\\temp.win-amd64-3.8\\Release\\swig\r\nC:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.27.29110\\bin\\HostX86\\x64\\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\\Users\\fedde\\PycharmProjects\\Bachelor-Thesis-Marginal-Sampling\\pipeline_for_sampling\\amici_models\\conversion_reaction_0 -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\ThirdParty\\gsl -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\ThirdParty\\sundials\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\ThirdParty\\SuiteSparse\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\include "-IC:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.27.29110\\ATLMFC\\include" "-IC:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.27.29110\\include" "-IC:\\Program Files (x86)\\Windows Kits\\NETFXSDK\\4.8\\include\\um" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\ucrt" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\shared" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\um" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\winrt" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\cppwinrt" /EHsc /Tpswig\\conversion_reaction_0_wrap.cpp /Fobuild\\temp.win-amd64-3.8\\Release\\swig\\conversion_reaction_0_wrap.obj /std:c++14\r\nconversion_reaction_0_wrap.cpp\r\nC:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.27.29110\\bin\\HostX86\\x64\\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\\Users\\fedde\\PycharmProjects\\Bachelor-Thesis-Marginal-Sampling\\pipeline_for_sampling\\amici_models\\conversion_reaction_0 -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\ThirdParty\\gsl -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\ThirdParty\\sundials\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\lib\\site-packages\\amici\\ThirdParty\\SuiteSparse\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\include -IC:\\Anaconda3\\envs\\Bachelor-Thesis\\include "-IC:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.27.29110\\ATLMFC\\include" "-IC:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.27.29110\\include" "-IC:\\Program Files (x86)\\Windows Kits\\NETFXSDK\\4.8\\include\\um" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\ucrt" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\shared" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\um" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\winrt" "-IC:\\Program Files (x86)\\Windows Kits\\10\\include\\10.0.18362.0\\cppwinrt" /EHsc /Tpconversion_reaction_0.cpp /Fobuild\\temp.win-amd64-3.8\\Release\\conversion_rea ...
# Failed building the model extension.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-3bbd49b6a7f5> in <module>
#      19 importer = pypesto.petab.PetabImporter(petab_problem) #PetabImporter class-object (subclass of AmiciObjectBuilder)
#      20 # create problem
# ---> 21 problem = importer.create_problem(guess_steadystate=False) #pypesto.problem class-object
#      22
#      23 amici_model = import_petab_problem(petab_problem)
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\pypesto\petab\importer.py in create_problem(self, objective, **kwargs)
#     324         """
#     325         if objective is None:
# --> 326             objective = self.create_objective(**kwargs)
#     327
#     328         prior = self.create_prior()
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\pypesto\petab\importer.py in create_objective(self, model, solver, edatas, force_compile, **kwargs)
#     228         # create model
#     229         if model is None:
# --> 230             model = self.create_model(force_compile=force_compile)
#     231         # create solver
#     232         if solver is None:
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\pypesto\petab\importer.py in create_model(self, force_compile, **kwargs)
#     101             logger.info(f"Compiling amici model to folder "
#     102                         f"{self.output_folder}.")
# --> 103             self.compile_model(**kwargs)
#     104         else:
#     105             logger.info(f"Using existing amici model in folder "
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\pypesto\petab\importer.py in compile_model(self, **kwargs)
#     158             shutil.rmtree(self.output_folder)
#     159
# --> 160         amici.petab_import.import_model(
#     161             sbml_model=self.petab_problem.sbml_model,
#     162             condition_table=self.petab_problem.condition_df,
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\amici\logging.py in wrapper_timer(*args, **kwargs)
#     192
#     193             tstart = time.perf_counter()
# --> 194             rval = func(*args, **kwargs)
#     195             tend = time.perf_counter()
#     196             spacers = ' ' * max(54 - len(description) - len(logger.name) -
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\amici\petab_import.py in import_model_sbml(sbml_model, condition_table, observable_table, measurement_table, model_name, model_output_dir, verbose, allow_reinit_fixpar_initcond, **kwargs)
#     545
#     546     # Create Python module from SBML model
# --> 547     sbml_importer.sbml2amici(
#     548         model_name=model_name,
#     549         output_dir=model_output_dir,
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\amici\sbml_import.py in sbml2amici(self, model_name, output_dir, observables, constant_parameters, sigmas, noise_distributions, verbose, assume_pow_positivity, compiler, allow_reinit_fixpar_initcond, compile, compute_conservation_laws, simplify, **kwargs)
#     343                 warnings.warn('AMICI C++ extensions have not been built. '
#     344                               'Generated model code, but unable to compile.')
# --> 345             exporter.compile_model()
#     346
#     347     def _process_sbml(self, constant_parameters: List[str] = None) -> None:
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\amici\logging.py in wrapper_timer(*args, **kwargs)
#     192
#     193             tstart = time.perf_counter()
# --> 194             rval = func(*args, **kwargs)
#     195             tend = time.perf_counter()
#     196             spacers = ' ' * max(54 - len(description) - len(logger.name) -
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\amici\ode_export.py in compile_model(self)
#    2170
#    2171         """
# -> 2172         self._compile_c_code(compiler=self.compiler,
#    2173                              verbose=self.verbose)
#    2174
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\site-packages\amici\ode_export.py in _compile_c_code(self, verbose, compiler)
#    2240         # result easily
#    2241         try:
# -> 2242             result = subprocess.run(script_args,
#    2243                                     cwd=module_dir,
#    2244                                     stdout=subprocess.PIPE,
#
# C:\Anaconda3\envs\Bachelor-Thesis\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         retcode = process.poll()
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#     514     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['C:\\Anaconda3\\envs\\Bachelor-Thesis\\python.exe', 'C:\\Users\\fedde\\PycharmProjects\\Bachelor-Thesis-Marginal-Sampling\\pipeline_for_sampling\\amici_models\\conversion_reaction_0\\setup.py', '--verbose', 'build_ext', '--build-lib=C:\\Users\\fedde\\PycharmProjects\\Bachelor-Thesis-Marginal-Sampling\\pipeline_for_sampling\\amici_models\\conversion_reaction_0']' returned non-zero exit status 1.

# %% [markdown]
# After importing the model, we need to define the objective function. This time we will do it via an external function that will be used then by pyPESTO instead of using the built-in ones.
#
# For numerical reasons we will implement the log likelihood and log prior.

# %%
def log_prior(x): # x[0] = theta, x[1] = c, x[2] = gamma
    """ Log prior function."""
    # assign variables from input x
    offset = x[1]
    precision = x[2] #assuming we receive gamma and not sigma^2
    
    # evaluate log normal-gamma prior
    l_prior = alpha * np.log(beta) + (alpha - 0.5) * np.log(lamda) + 0.5 * (np.log(kappa) - np.log(2) - np.log(np.pi)
                - np.log(scipy.special.gamma(alpha))
    
    return l_prior


def negative_log_posterior(x):
    """ Negative log posterior function."""
    
    # experimental data
    data = np.asarray(petab_problem.measurement_df.measurement)
    
    # simulate model with AMICI
    _simu = my_internal_amici_objective(x, [0], return_dict=True)
    
    # return here the observable
    simulation = _simu['rdatas'][0].y[:, 0]
    
    # evaluate standard log likelihood
    sum = 0
    for k in range(N):
        sum += (y[k] - h[k])**2
    l_llh = N/2 * (np.log(lamda) - np.log(2*np.pi)) - lamda * 0.5 * sum
    
    # evaluate log normal-gamma prior
    l_prior = log_prior(x)
    
    # return NEGATIVE log posterior (required for pyPESTO)
    return -(l_llh + l_prior)

# %% [markdown]
# Now that we have the objective function defined, we need to create a pyPESTO problem.

# %%
def standard_sampling():
    """Creates a pyPESTO problem."""
    objective = pypesto.Objective(fun=negative_log_posterior)
    problem = pypesto.Problem(objective=objective,  # objective function
                              lb=[-5, -5, -np.inf, -np.inf],  # lower bounds
                              ub=[5, 5, np.inf, np.inf],  # upper bounds
                              x_names=['k1', 'k2', 'offset', 'sigma'],  # parameter names
                              x_scales=['log', 'log', 'log', 'log'])  # parameter scale
    return problem

# %%
### Prior dependent paramters
# center the scaling parameter
mu=
# std for scaling parameter --> higher = more constrained / lower = more relaxed
alpha=
# center the sigma parameter
beta=
# std for scaling parameter --> higher = more constrained / lower = more relaxed
kappa=

# create the estimation problem
problem = standard_sampling()

# MCMC chain length
n_samples=

# call the sampler of choice
sampler = sample.AdaptiveMetropolisSampler()

# %% [markdown]
# Now we can perform the actual sampling.

# %%
# Define number of runs
runs = 1

save_results = False # for testing just set to False

# Loop over n runs
for n in range(runs):
    # set initial random seed
    np.random.seed(n)
    # perform MCMC sampling
    result = sample.sample(problem, n_samples=n_samples, sampler=sampler,
                           x0=np.array([-1.2741, -0.6160, 0.7826, -3.6839]))
    # calculate effective sample size
    sample.effective_sample_size(result=result)

    # save the results as a pickle object
    if save_results:
        with open('result_SS_'+str(n)+'.pickle', 
                  'wb') as result_file:
            pickle.dump(result.sample_result, result_file)
            result_file.close()

# %% [markdown]
# There are some built-in visualization functions that one can use.

# %%
# Visualize the log posterior trace
ax = visualize.sampling_fval_trace(result, size=(12,5), full_trace=True)
# Visualize the parameter trace
ax = visualize.sampling_parameters_trace(result, use_problem_bounds=False, full_trace=True, size=(12,5))
# Visualize the one-dimensional marginals --> Important!
ax = visualize.sampling_1d_marginals(result, size=(12,5))
